# %%
import pandas as pd

# %%
file = '/data/uurgeg_344_2011-2020.txt'

# %%
df = pd.read_csv(file, skiprows=30)

# %%
df[20:30]
# Out:
#     # STN  YYYYMMDD     HH     DD     FH     FF     FX      T   T10N     TD  \
# 20    344  20110101     21    300     20     20     40     -4           -12
# 21    344  20110101     22    280     10     10     30      8             1
# 22    344  20110101     23    330     20     30     30      7            -5
# 23    344  20110101     24    330     20     30     40     19    -54      6
# 24    344  20110102      1    320     30     30     50     20             5
# 25    344  20110102      2    300     30     30     60     17            -5
# 26    344  20110102      3    330     10     10     30     14            -7
# 27    344  20110102      4    310     20     30     40     -1           -16
# 28    344  20110102      5    300     30     30     40     -4           -25
# 29    344  20110102      6    320     40     30     60     21    -47      4
#
#     ...     VV      N      U     WW     IX      M     R      S     O      Y
# ...

# %%
time_filter = (df['   HH']<=8) | (df['   HH']>=20) 
time_filter.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name:    HH, dtype: bool

# %%
time_filter = df[time_filter]

# %%
temp_filter = time_filter['    T']>=240
temp_filter = time_filter[temp_filter]
temp_filter.head(20)
# Out:
#        # STN  YYYYMMDD     HH     DD     FH     FF     FX      T   T10N  \
# 4255     344  20110627      8    150     40     40     70    250
# 4267     344  20110627     20    110     20     30     30    272
# 4269     344  20110627     22    120     30     30     40    249
# 4270     344  20110627     23    130     20     10     40    251
# 4273     344  20110628      2    130     30     40     50    242
# 4277     344  20110628      6    110     20     20     50    260    180
# 4278     344  20110628      7    210     20     40     80    249
# 13711    344  20120725      8     50     10     10     20    244
# 14287    344  20120818      8    150     40     40     80    247
# 14309    344  20120819      6    140     20     20     40    241    158
# 14310    344  20120819      7    170     30     40     50    254
# 14311    344  20120819      8    180     40     30     70    272
# 14323    344  20120819     20    130     30     30     70    243
# ...

# %%
recent_years_filter = temp_filter['YYYYMMDD'] >= 20200101
recent_years_filter = temp_filter[recent_years_filter]
len(recent_years_filter['YYYYMMDD'].unique())
# Out:
# 14

# %%
len(temp_filter['YYYYMMDD'].unique())
# Out:
# 66

# %%
df.columns
# Out:
# Index([u'# STN', u'YYYYMMDD', u'   HH', u'   DD', u'   FH', u'   FF', u'   FX',
#        u'    T', u' T10N', u'   TD', u'   SQ', u'    Q', u'   DR', u'   RH',
#        u'    P', u'   VV', u'    N', u'    U', u'   WW', u'   IX', u'    M',
#        u'    R', u'    S', u'    O', u'    Y'],
#       dtype='object')

# %%
len(df)
# Out:
# 87672
